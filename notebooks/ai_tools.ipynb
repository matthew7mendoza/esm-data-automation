# %% [markdown]
# # Follow the instructions to use the tool
#
# ## 1. Upload all your files to the input folder
#
# ## 2. Activate the Agent
#
# ## 3. Select document type you are trying to fill out

# %%
import sys
import os
from pathlib import Path
from dotenv import load_dotenv

project_root = str(Path("..").resolve())
if project_root not in sys.path:
    sys.path.append(project_root)
from src.generator import generate_document_draft
load_dotenv(Path("../.env"))

API_KEY = os.environ.get("GEMINI_API_KEY")

# Options include ("DMP", "README", "DOI")
TARGET_DOCUMENT_TYPE = "DMP"
INPUT_DIRECTORY = Path("../inputs")

generate_document_draft(
    target_document_type=TARGET_DOCUMENT_TYPE,
    input_dir=INPUT_DIRECTORY,
    api_key=API_KEY
)
# Out:
# AI AGENT ACTIVATED
# Configuration loaded. Found 1 supported file(s):
#  -> Research Opportunites List.pdf
#
# --- Assembling knowledge base for DMP ---
# Reading: Research Opportunites List.pdf...
#
#  ---Processing DMP extraction via LLM---
# Extraction complete.
#
# ---- GENERATED DMP DRAFT ----
#
# What opportunity is from UCLA?
# > The Cultivating Interest in Research Careers (CIRC) program, LA Hacks 2026, and the Breaking Barriers in STEM Conference.
#
# What is the deadline for the STARS program?
# > Rolling admissions until March 2, 2026, with a priority deadline of January 12, 2026.
#
# ----- MISSING INFORMATION -----
# The AI could not find answers to these questions in your documents:
#
# - How many students participate in the Capital One opportunity?
